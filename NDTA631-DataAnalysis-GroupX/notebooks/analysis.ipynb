# %%
import sys
import os
sys.path.append(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\scripts")
import pandas as pd
from data_pipeline import load_data, clean_data, filter_south_africa_data

df1 = load_data(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\data\raw\employment.csv ", 'employment')
df2 = load_data(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\data\raw\poverty.csv", 'poverty')

df1_clean = clean_data(df1, 'employment')
df2_clean = clean_data(df2, 'poverty')

df1_filter = filter_south_africa_data(df1_clean, "REF_AREA_LABEL", "employment_sa_clean")
df2_filter = filter_south_africa_data(df2_clean, "REF_AREA_LABEL", "poverty_sa_clean")

if df1_filter is not None and df2_filter is not None:
    print("Descriptive Statistics for employment:")
    print(df1_filter.describe())
    print("\nDescriptive Statistics for poverty:")
    print(df2_filter.describe())
    print("\nMissing Values in employment:", df1_filter.isnull().sum())
    print("\nMissing Values in poverty:", df2_filter.isnull().sum())
else:
    print("Error: Could not load or clean datasets.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 5
#       3 sys.path.append(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\scripts")
#       4 import pandas as pd
# ----> 5 from data_pipeline import load_data, clean_data, filter_south_africa_data
#       7 df1 = load_data(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\data\raw\employment.csv ", 'employment')
#       8 df2 = load_data(r"C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\data\raw\poverty.csv", 'poverty')
#
# ImportError: cannot import name 'filter_south_africa_data' from 'data_pipeline' (C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\scripts\data_pipeline.py)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r'C:\Users\Admin\Desktop\GroupX_DataAnalysis\NDTA631-DataAnalysis-GroupX\scripts\database.db')
df_employment = pd.read_sql('SELECT * FROM employment', conn)
df_poverty = pd.read_sql('SELECT * FROM poverty', conn)
conn.close()

print(df_employment.head())
print(df_poverty.head())
# Out:
#   FREQ FREQ_LABEL REF_AREA              REF_AREA_LABEL  \
# 0    A     Annual      ABW                       Aruba
# 1    A     Annual      AFG                 Afghanistan
# 2    A     Annual      AFW  Africa Western and Central
# 3    A     Annual      AGO                      Angola
# 4    A     Annual      ALB                     Albania
#
#                      INDICATOR  \
# 0  WB_WDI_SL_EMP_TOTL_SP_NE_ZS
# 1  WB_WDI_SL_EMP_TOTL_SP_NE_ZS
# 2  WB_WDI_SL_EMP_TOTL_SP_NE_ZS
# 3  WB_WDI_SL_EMP_TOTL_SP_NE_ZS
# 4  WB_WDI_SL_EMP_TOTL_SP_NE_ZS
#
#                                      INDICATOR_LABEL UNIT_MEASURE  \
# 0  Employment to population ratio, 15+, total (%)...           PT
# 1  Employment to population ratio, 15+, total (%)...           PT
# 2  Employment to population ratio, 15+, total (%)...           PT
# 3  Employment to population ratio, 15+, total (%)...           PT
# 4  Employment to population ratio, 15+, total (%)...           PT
#
# ...
